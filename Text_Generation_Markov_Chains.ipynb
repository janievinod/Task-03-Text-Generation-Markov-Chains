# %% [markdown]
# <a href="https://colab.research.google.com/github/janievinod/Task-03-Text-Generation-Markov-Chains/blob/main/Text_Generation_Markov_Chains.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install markovify spacy nltk
# !python -m spacy download en_core_web_sm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 69.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
import re
import markovify
import nltk
from nltk.corpus import gutenberg
import warnings
warnings.filterwarnings('ignore')

# Download the Gutenberg dataset
nltk.download('gutenberg')
# Load the modernized English pipeline for spaCy
nlp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.

# %%
# Fixed the article's typos in the filenames here
hamlet = gutenberg.raw('shakespeare-hamlet.txt')
macbeth = gutenberg.raw('shakespeare-macbeth.txt')
caesar = gutenberg.raw('shakespeare-caesar.txt')

# Cleaning function to strip layout noise and formatting
def text_cleaner(text):
    text = re.sub(r'--', ' ', text)
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'(\b|\s+-?|^-?)(\d+|\d*\.\d+)\b','', text)
    text = ' '.join(text.split())
    return text

# Clean chapters and apply text cleaner
hamlet = text_cleaner(re.sub(r'Chapter \d+', '', hamlet))
caesar = text_cleaner(re.sub(r'Chapter \d+', '', caesar))
macbeth = text_cleaner(re.sub(r'Chapter \d+', '', macbeth))

# Parse texts using spaCy to extract clean sentences
print("Parsing text with spaCy (this may take a moment)...")
hamlet_doc = nlp(hamlet)
macbeth_doc = nlp(macbeth)
caesar_doc = nlp(caesar)

hamlet_sents = ' '.join([sent.text for sent in hamlet_doc.sents if len(sent.text) > 1])
macbeth_sents = ' '.join([sent.text for sent in macbeth_doc.sents if len(sent.text) > 1])
caesar_sents = ' '.join([sent.text for sent in caesar_doc.sents if len(sent.text) > 1])

# Combine into a unified Shakespeare dataset
shakespeare_sents = hamlet_sents + " " + macbeth_sents + " " + caesar_sents
print("Preprocessing complete!")
# Out:
# Parsing text with spaCy (this may take a moment)...
# Preprocessing complete!

# %%
# 1. Take interactive user input
user_prompt = input("Enter a starting word (try 'The', 'To', 'Hamlet', 'Brutus', or 'Our'): ")

print(f"\n--- Generating Shakespearean sentences starting with '{user_prompt}' ---")

# 2. Generate text based on your input
success_count = 0
for i in range(5):
    try:
        # strict=False allows the model to use the word even if it wasn't the exact start of a sentence in the original text
        generated = generator.make_sentence_with_start(user_prompt, strict=False)
        if generated:
            print(f"{i+1}: {generated}")
            success_count += 1
    except Exception:
        continue

if success_count == 0:
    print(f"⚠️ Look like the model struggled to connect '{user_prompt}' to a valid sentence path.")
    print("Tip: Try common words or capitalized names from the text (e.g., 'I', 'And', 'Caesar', 'What').")
# Out:
# Enter a starting word (try 'The', 'To', 'Hamlet', 'Brutus', or 'Our'): Brutus
#
# --- Generating Shakespearean sentences starting with 'Brutus' ---
# 1: Brutus rose against Caesar , I come to fetch you to the Senate house , And he to England shall along with you ?
# 2: Brutus what shall be done ? Priest .
# 3: Brutus at his house  three parts of him Is ours alreadie , and the Houre , runs through the roughest Day Banq .
# 4: Brutus liuing ; but will follow The Fortunes and Affayres of Noble Brutus , The Heauens speede thee in thine enterprize .
# 5: Brutus liuing ; but will follow The Fortunes and Affayres of Noble Brutus , Hath told you Caesar was Ambitious  And sure he is an Honourable man .
